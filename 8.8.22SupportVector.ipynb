# %% [markdown]
#    8.8.22                               SUPPORT VECTOR MACHINE
#                 support vectors are data points(data can be seperated into two distinct classes
#                    using straightline or hyperbole.)It support regression and classification.

# %% [markdown]
#  STEP1: Importing the Libraies

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# STEP2: Loding the Dataset

# %%
dataset = pd.read_csv('50_Startups.csv')

# %%
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# STEP:3 get_dummies() TO CONVERT STRING DATA INTO BYTESTREAM(0'S &1'S)

# %%
datasets=pd.get_dummies(dataset,drop_first=True)

# %%
datasets
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0   165349.20       136897.80        471784.10  192261.83              0
# 1   162597.70       151377.59        443898.53  191792.06              0
# 2   153441.51       101145.55        407934.54  191050.39              1
# 3   144372.41       118671.85        383199.62  182901.99              0
# 4   142107.34        91391.77        366168.42  166187.94              1
# 5   131876.90        99814.71        362861.36  156991.12              0
# 6   134615.46       147198.87        127716.82  156122.51              0
# 7   130298.13       145530.06        323876.68  155752.60              1
# 8   120542.52       148718.95        311613.29  152211.77              0
# 9   123334.88       108679.17        304981.62  149759.96              0
# 10  101913.08       110594.11        229160.95  146121.95              1
# 11  100671.96        91790.61        249744.55  144259.40              0
# ...

# %% [markdown]
# STEP:4 ASSINGING INPUT AND OUTPUT DATA

# %%
indep=datasets[['R&D Spend','Administration', 'Marketing Spend','State_Florida', 'State_New York']]
dep=datasets[['Profit']]

# %%
indep
# Out:
#     R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 0   165349.20       136897.80        471784.10              0               1
# 1   162597.70       151377.59        443898.53              0               0
# 2   153441.51       101145.55        407934.54              1               0
# 3   144372.41       118671.85        383199.62              0               1
# 4   142107.34        91391.77        366168.42              1               0
# 5   131876.90        99814.71        362861.36              0               1
# 6   134615.46       147198.87        127716.82              0               0
# 7   130298.13       145530.06        323876.68              1               0
# 8   120542.52       148718.95        311613.29              0               1
# 9   123334.88       108679.17        304981.62              0               0
# 10  101913.08       110594.11        229160.95              1               0
# ...

# %%
dep
# Out:
#        Profit
# 0   192261.83
# 1   191792.06
# 2   191050.39
# 3   182901.99
# 4   166187.94
# 5   156991.12
# 6   156122.51
# 7   155752.60
# 8   152211.77
# 9   149759.96
# 10  146121.95
# 11  144259.40
# 12  141585.52
# 13  134307.35
# 14  132602.65
# 15  129917.04
# 16  126992.93
# 17  125370.37
# 18  124266.90
# 19  122776.86
# 20  118474.03
# 21  111313.02
# 22  110352.25
# 23  108733.99
# 24  108552.04
# 25  107404.34
# 26  105733.54
# 27  105008.31
# 28  103282.38
# 29  101004.64
# 30   99937.59
# 31   97483.56
# 32   97427.84
# 33   96778.92
# 34   96712.80
# 35   96479.51
# 36   90708.19
# 37   89949.14
# 38   81229.06
# 39   81005.76
# 40   78239.91
# 41   77798.83
# 42   71498.49
# 43   69758.98
# 44   65200.33
# 45   64926.08
# 46   49490.75
# 47   42559.73
# 48   35673.41
# 49   14681.40

# %% [markdown]
# STEP: 5 SPLITING TRAIN/TEST DATA

# %%
#spliting train /test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %% [markdown]
#  STEP:6  MODEL CREATION IN SVM

# %%
from sklearn.svm import SVR
#importing SupportVectorRegresion from sklearn libraries#
r=SVR(kernel='linear')
#SVR should be in captial,here arguments are passes by default or we can also pass
#Here we used linear parameter to get good r_score value then model should be good
r.fit(x_train,y_train)
# Out:
# C:\Users\Yaazh\anaconda3\envs\ai\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='linear')

# %% [markdown]
#  STEP:8 PREDICTION

# %%
y_pred=r.predict(x_test)

# %%
y_pred
# Out:
# array([110563.42583215, 126719.62664162, 129173.42209756,  75717.35691582,
#        164677.02542245, 111109.52854668,  68874.15891396, 104265.36318337,
#        111629.03886925, 155765.39975869,  96608.12022912,  88407.9789518 ,
#        113473.64412438,  95395.58821236, 122943.81923043, 152397.05783211,
#        145908.88357293])

# %% [markdown]
#  STEP:9 EVALUTION METRICS

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.8753348561601315

# %% [markdown]
#  STEP:10 SAVE THE MODEL IF THE MODEL HAS GOOD R_SCORE VALUE

# %%
import pickle
filename='svm_final.sav'
pickle.dump(r,open(filename,"wb"))

# %%
model=pickle.load(open(filename,"rb"))

# %% [markdown]
#  STEP:11 GETTING USER INPUTS

# %%
rd_input=float(input("R&D:"))
admin_input=float(input("Admin"))
mark_input=float(input("Marketing "))
fol_input=int(input("State_flo 0 or 1:"))
new_input=int(input("State_new 0 or 1:"))
# Out:
# R&D:3000
# Admin4000
# Marketing 10000
# State_flo 0 or 1:0
# State_new 0 or 1:0

# %%
result=model.predict([[rd_input,admin_input,mark_input,fol_input,new_input]])
# Out:
# C:\Users\Yaazh\anaconda3\envs\ai\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   "X does not have valid feature names, but"

# %%
result
# Out:
# array([50312.65750253])
